# %% [markdown]
# # Problem:

# %% [markdown]
# ![image.png](attachment:0aea93d0-3c34-47c6-a231-97d776d79ae5.png)

# %% [markdown]
# ![image.png](attachment:0815df49-0aee-4858-95f1-e1a7972d6e43.png)

# %% [markdown]
# ![image.png](attachment:30a6db25-8c02-4ec3-9a4c-1652f78722ee.png)

# %% [markdown]
# # Solu

# %%
N, M = list(map(int, input().split(" ")))
ss=list(range(1,N,2))
ss=ss+ss[::-1]
ss.insert(len(ss)//2,'WELCOME')
for i in range(N):
    if type(ss[i])==int:
        print(('.|.'*ss[i]).center(M,'-'))
    else:
        print((ss[i]).center(M,'-'))
# Out:
#  9 27
# ------------.|.------------
# ---------.|..|..|.---------
# ------.|..|..|..|..|.------
# ---.|..|..|..|..|..|..|.---
# ----------WELCOME----------
# ---.|..|..|..|..|..|..|.---
# ------.|..|..|..|..|.------
# ---------.|..|..|.---------
# ------------.|.------------
